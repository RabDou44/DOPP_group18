# %% [markdown]
# Output: flight_times.csv (europe_flights.csv)

# %%
# set up
import requests
import pandas as pd
import random

airlab_api_params = {
    "api_key" : "8ffb5e97-7a50-4773-b2d9-8638ec08bc75",
}

airlab_ex_param = {
    "api_key" : "8ffb5e97-7a50-4773-b2d9-8638ec08bc75",
    "dep_iata" : "ANR"
}

# %% [markdown]
# AirLabs API
#
# to get information about times schedules in Europe we draw info from airlbas api. In our project we subset our citie

# %%
PATH_IATA_CODES = "./datasets/airport-codes.csv" # we get largest largest airports all over the world

# %% [markdown]
# Summary and filtering largest airports

# %%
EURO_IATA_CODES = pd.read_csv(PATH_IATA_CODES)
EURO_IATA_CODES['type'].unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
# EURO_IATA_CODES.loc[EURO_IATA_CODES["type"] == 'large_airport' & EURO_IATA_CODES['continent'] == 'EU']
EU_LARGE = EURO_IATA_CODES.loc[(EURO_IATA_CODES["type"].isin(['large_airport','medium_airport']))  &  (EURO_IATA_CODES['continent'].isin(["EU"]) )][["name","iata_code","iso_region","iso_country","coordinates"]]

## exclude islands and unaccessible airports

airports_to_exclude= ["HER", "NaN","PMI", "LPA", "TFS", "TFN"]
# island countries
countries_to_exclude = ["IS","IE"]

FINAL_AIRPORTS = EU_LARGE.loc[(~EU_LARGE['iso_country'].isin(countries_to_exclude))  
                              & (~EU_LARGE['iata_code'].isin(airports_to_exclude))
                              & (~EU_LARGE['iata_code'].isna())].reset_index(drop=True)
FINAL_AIRPORTS
# Out:
#                                        name iata_code iso_region iso_country  \
# 0                           Bezmer Air Base       JAM      BG-28          BG
# 1           PriÅ¡tina International Airport       PRN      XK-01          XK
# 2    Antwerp International Airport (Deurne)       ANR     BE-VAN          BE
# 3                          Brussels Airport       BRU     BE-BRU          BE
# 4          Brussels South Charleroi Airport       CRL     BE-WHT          BE
# ..                                      ...       ...        ...         ...
# 783                        Balakovo Airport       BWO     RU-SAR          RU
# 784                 Saratov Central Airport       RTW     RU-SAR          RU
# 785               Ufa International Airport       UFA      RU-BA          RU
# 786          Kurumoch International Airport       KUF     RU-SAM          RU
# 787                  Smolensk North Airport       LNX     RU-SMO          RU
#
#                                coordinates
# 0             26.3521995544, 42.4548988342
# 1                       21.035801, 42.5728
# 2             4.46027994156, 51.1893997192
# 3        4.48443984985, 50.901401519800004
# 4                       4.45382, 50.459202
# ..                                     ...
# 783           47.7456016541, 51.8582992554
# 784  46.04669952392578, 51.564998626708984
# 785       55.874401092529, 54.557498931885
# 786        50.16429901123, 53.504901885986
# 787                         32.025, 54.824
#
# [788 rows x 5 columns]

# %% [markdown]
# Save selected large airports to CSV

# %%
FINAL_AIRPORTS.to_csv("./datasets/AIRPORT_SET.csv")

# %%
FINAL_AIRPORTS.loc[FINAL_AIRPORTS['iso_country'] == "SK"]
# Out:
#                          name iata_code iso_region iso_country  \
# 663  M. R. Å tefÃ¡nik Airport       BTS      SK-BL          SK
# 664           KoÅ¡ice Airport       KSC      SK-KI          SK
# 665        PieÅ¡Å¥any Airport       PZY      SK-TA          SK
# 666            SliaÄ Airport       SLD      SK-BC          SK
# 667      Poprad-Tatry Airport       TAT      SK-KI          SK
# 668           Å½ilina Airport       ILZ      SK-ZI          SK
#
#                                coordinates
# 663   17.21269989013672, 48.17020034790039
# 664  21.241100311279297, 48.66310119628906
# 665  17.828399658203125, 48.62519836425781
# 666   19.13409996032715, 48.63779830932617
# 667            20.2411003113, 49.073600769
# 668      18.6135005951, 49.231498718299996

# %%
CODES = list(FINAL_AIRPORTS["iata_code"])

sample_CODES = random.sample(CODES, 50)
sample_CODES
# Out:
# ['ZIA',
#  'EDI',
#  'SIR',
#  'LBC',
#  'TIV',
#  'MRS',
#  'DGP',
#  'ZMG',
#  'SKG',
#  'SZW',
#  'CMF',
#  'QLT',
#  'CSF',
#  'MIK',
#  'GOA',
#  'MOL',
#  'LWR',
#  'RYG',
#  'BLK',
#  'MST',
#  'NTE',
#  'ZTH',
#  'GLZ',
#  'LHA',
#  'LLA',
#  'HVG',
#  'AOK',
#  'STN',
#  'HZB',
#  'RRS',
#  'BZY',
#  'PEV',
#  'AOI',
#  'EXT',
#  'BVG',
#  'CQF',
#  'SVO',
#  'JKG',
#  'BJF',
#  'EIB',
#  'VRK',
#  'BAY',
#  'EPU',
#  'SJJ',
#  'NHT',
#  'GEV',
#  'SEK',
#  'BWF',
#  'LME',
#  'FCO']

# %%
"CDG" in sample_CODES
# Out:
# False

# %%
def get_flight_duration(codes):
    
    # download
    data = []
    for code in codes:
        queryX = {
            "api_key" : "8ffb5e97-7a50-4773-b2d9-8638ec08bc75",
            "dep_iata" :  f"{code}"
        }

        req_get = requests.get("https://airlabs.co/api/v9/schedules?",params= queryX)        
        DF = parse_response(req_get)
        if len(DF) > 0:
            DF = filter_clean_codes(DF, codes)
            data.append(DF)

    DF["route"] = DF.apply(lambda row: set([row["dep"], row["arr"]]), axis=1)
    DF = DF.loc[["route","time"]]
    DF.drop_duplicates(inplace=True, ignore_index=True)
  
    # concat all and return 
    return pd.concat(data, ignore_index=True)



def parse_response(api_response):
    """
    Keyword arguments:
    api_response -- GET response
    Return: pd.DataFrame of flight routes
    """

    j_resp = api_response.json()
    flight_list = j_resp['response']
    
    flights = []
    for fl in flight_list:
        one_flight = {"dep":fl['dep_iata'],
                      "arr":fl['arr_iata'],
                      "time":fl['duration']}
        flights.append(one_flight)

    print(flight_list)
    return pd.DataFrame(flights)

def filter_clean_codes(flight_set, codes):
    df = flight_set[ (flight_set["dep"].isin(codes)) & (flight_set["arr"].isin(codes))]
    # uDF = df.loc[["route","time"]]
    return df.drop_duplicates(ignore_index=True)

# %%
Flights= get_flight_duration(CODES)
Flights.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 Flights= get_flight_duration(CODES)
#       2 Flights.head()
#
# Input In [84], in get_flight_duration(codes)
#       6 queryX = {
#       7     "api_key" : "8ffb5e97-7a50-4773-b2d9-8638ec08bc75",
#       8     "dep_iata" :  f"{code}"
#       9 }
#      11 req_get = requests.get("https://airlabs.co/api/v9/schedules?",params= queryX)
# ---> 12 DF = parse_response(req_get)
#      13 if len(DF) > 0:
#      14     DF = filter_clean_codes(DF, codes)
#
# Input In [84], in parse_response(api_response)
#      27 """
#      28 Keyword arguments:
#      29 api_response -- GET response
#      30 Return: pd.DataFrame of flight routes
#      31 """
#      33 j_resp = api_response.json()
# ---> 34 flight_list = j_resp['response']
#      36 flights = []
#      37 for fl in flight_list:
#
# KeyError: 'response'

# %%
ksc = Flights.loc[ (Flights["dep"]== "KSC") | (Flights["arr"]== "KSC")].reset_index(drop=True)

# %%
Flights.to_csv("./datasets/Flights1.csv")

# %%
Flights["route"] = Flights.apply(lambda row: str( set([row["dep"], row["arr"]]) ), axis=1)
Flights
# Out:
#       dep  arr  time           route
# 0     PRN  STR   125  {'PRN', 'STR'}
# 1     PRN  DUS   160  {'DUS', 'PRN'}
# 2     PRN  DUS   165  {'DUS', 'PRN'}
# 3     PRN  MUC   120  {'MUC', 'PRN'}
# 4     PRN  HAM   165  {'PRN', 'HAM'}
# ...   ...  ...   ...             ...
# 2271  KUF  LED   145  {'KUF', 'LED'}
# 2272  KUF  VKO   120  {'VKO', 'KUF'}
# 2273  KUF  LED   150  {'KUF', 'LED'}
# 2274  KUF  SVO   115  {'SVO', 'KUF'}
# 2275  KUF  SVO   110  {'SVO', 'KUF'}
#
# [2276 rows x 4 columns]

# %%
FlightsShort = Flights[["route", "time"]].groupby(["route"]).mean()
FlightsShort.reset_index(inplace=True)
FlightsShort["route"] = FlightsShort["route"].apply(lambda x: eval(x))
FlightsShort["dep"]
# Out:
#            route   time
# 0     {AAL, AMS}   85.0
# 1     {AAQ, LED}  170.0
# 2     {AMS, ABZ}   85.0
# 3     {ABZ, LGW}   95.0
# 4     {ACE, AGP}  130.0
# ...          ...    ...
# 1464  {ZRH, OTP}  150.0
# 1465  {ZRH, PRN}  127.5
# 1466  {ZRH, RVN}  205.0
# 1467  {ZRH, STR}   45.0
# 1468  {ZTH, ATH}   62.5
#
# [1469 rows x 2 columns]

# %%
FlightsShort.to_csv("./datasets/europe_flights.csv")

# %%
queryCDG = {
    "api_key" : "8ffb5e97-7a50-4773-b2d9-8638ec08bc75",
    "dep_iata" :  "CDG"   
}


res_ex = requests.get("https://airlabs.co/api/v9/schedules?",params= queryCDG)
js_res = res_ex.json()
js_res["response"]
# Out:
# [{'airline_iata': 'AH',
#   'airline_icao': 'DAH',
#   'flight_iata': 'AH1149',
#   'flight_icao': 'DAH1149',
#   'flight_number': '1149',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2D',
#   'dep_gate': 'B31',
#   'dep_time': '2024-01-20 14:00',
#   'dep_time_utc': '2024-01-20 13:00',
#   'dep_estimated': '2024-01-20 14:34',
#   'dep_estimated_utc': '2024-01-20 13:34',
#   'dep_actual': '2024-01-20 14:34',
#   'dep_actual_utc': '2024-01-20 13:34',
#   'arr_iata': 'CFK',
#   'arr_icao': 'DAOI',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:35',
#   'arr_time_utc': '2024-01-20 15:35',
#   'arr_estimated': '2024-01-20 16:43',
#   'arr_estimated_utc': '2024-01-20 15:43',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 155,
#   'delayed': 8,
#   'dep_delayed': 34,
#   'arr_delayed': 8,
#   'aircraft_icao': 'B738',
#   'arr_time_ts': 1705764900,
#   'dep_time_ts': 1705755600,
#   'arr_estimated_ts': 1705765380,
#   'dep_estimated_ts': 1705757640,
#   'dep_actual_ts': 1705757640},
#  {'airline_iata': 'AH',
#   'airline_icao': 'DAH',
#   'flight_iata': 'AH1001',
#   'flight_icao': 'DAH1001',
#   'flight_number': '1001',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2D',
#   'dep_gate': 'B29',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:35',
#   'dep_estimated_utc': '2024-01-20 13:35',
#   'dep_actual': '2024-01-20 14:37',
#   'dep_actual_utc': '2024-01-20 13:37',
#   'arr_iata': 'ALG',
#   'arr_icao': 'DAAG',
#   'arr_terminal': 'I',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:45',
#   'arr_time_utc': '2024-01-20 15:45',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 135,
#   'delayed': None,
#   'dep_delayed': 7,
#   'arr_delayed': None,
#   'aircraft_icao': 'B738',
#   'arr_time_ts': 1705765500,
#   'dep_time_ts': 1705757400,
#   'dep_estimated_ts': 1705757700,
#   'dep_actual_ts': 1705757820},
#  {'airline_iata': 'A3',
#   'airline_icao': 'AEE',
#   'flight_iata': 'A31441',
#   'flight_icao': 'AEE1441',
#   'flight_number': '1441',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '1',
#   'dep_gate': '64',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:37',
#   'dep_estimated_utc': '2024-01-20 13:37',
#   'dep_actual': '2024-01-20 14:37',
#   'dep_actual_utc': '2024-01-20 13:37',
#   'arr_iata': 'FRA',
#   'arr_icao': 'EDDF',
#   'arr_terminal': '1',
#   'arr_gate': 'A58',
#   'arr_baggage': '3',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'arr_estimated': '2024-01-20 15:47',
#   'arr_estimated_utc': '2024-01-20 14:47',
#   'arr_actual': '2024-01-20 15:47',
#   'arr_actual_utc': '2024-01-20 14:47',
#   'cs_airline_iata': 'LH',
#   'cs_flight_number': '1035',
#   'cs_flight_iata': 'LH1035',
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 7,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'arr_estimated_ts': 1705762020,
#   'dep_estimated_ts': 1705757820,
#   'arr_actual_ts': 1705762020,
#   'dep_actual_ts': 1705757820},
#  {'airline_iata': 'AF',
#   'airline_icao': 'AFR',
#   'flight_iata': 'AF688',
#   'flight_icao': 'AFR688',
#   'flight_number': '688',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'M49',
#   'dep_time': '2024-01-20 14:15',
#   'dep_time_utc': '2024-01-20 13:15',
#   'dep_estimated': '2024-01-20 14:37',
#   'dep_estimated_utc': '2024-01-20 13:37',
#   'dep_actual': '2024-01-20 14:37',
#   'dep_actual_utc': '2024-01-20 13:37',
#   'arr_iata': 'ATL',
#   'arr_icao': 'KATL',
#   'arr_terminal': 'I',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 18:05',
#   'arr_time_utc': '2024-01-20 23:05',
#   'arr_estimated': '2024-01-20 18:11',
#   'arr_estimated_utc': '2024-01-20 23:11',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 590,
#   'delayed': 22,
#   'dep_delayed': 22,
#   'arr_delayed': 6,
#   'aircraft_icao': 'B772',
#   'arr_time_ts': 1705791900,
#   'dep_time_ts': 1705756500,
#   'arr_estimated_ts': 1705792260,
#   'dep_estimated_ts': 1705757820,
#   'dep_actual_ts': 1705757820},
#  {'airline_iata': 'DL',
#   'airline_icao': 'DAL',
#   'flight_iata': 'DL8606',
#   'flight_icao': 'DAL8606',
#   'flight_number': '8606',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'M49',
#   'dep_time': '2024-01-20 14:15',
#   'dep_time_utc': '2024-01-20 13:15',
#   'dep_estimated': '2024-01-20 14:37',
#   'dep_estimated_utc': '2024-01-20 13:37',
#   'dep_actual': '2024-01-20 14:37',
#   'dep_actual_utc': '2024-01-20 13:37',
#   'arr_iata': 'ATL',
#   'arr_icao': 'KATL',
#   'arr_terminal': 'I',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 18:05',
#   'arr_time_utc': '2024-01-20 23:05',
#   'arr_estimated': '2024-01-20 18:11',
#   'arr_estimated_utc': '2024-01-20 23:11',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '688',
#   'cs_flight_iata': 'AF688',
#   'status': 'active',
#   'duration': 590,
#   'delayed': 22,
#   'dep_delayed': 22,
#   'arr_delayed': 6,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705791900,
#   'dep_time_ts': 1705756500,
#   'arr_estimated_ts': 1705792260,
#   'dep_estimated_ts': 1705757820,
#   'dep_actual_ts': 1705757820},
#  {'airline_iata': 'KL',
#   'airline_icao': 'KLM',
#   'flight_iata': 'KL2299',
#   'flight_icao': 'KLM2299',
#   'flight_number': '2299',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'M49',
#   'dep_time': '2024-01-20 14:15',
#   'dep_time_utc': '2024-01-20 13:15',
#   'dep_estimated': '2024-01-20 14:37',
#   'dep_estimated_utc': '2024-01-20 13:37',
#   'dep_actual': '2024-01-20 14:37',
#   'dep_actual_utc': '2024-01-20 13:37',
#   'arr_iata': 'ATL',
#   'arr_icao': 'KATL',
#   'arr_terminal': 'I',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 18:05',
#   'arr_time_utc': '2024-01-20 23:05',
#   'arr_estimated': '2024-01-20 18:11',
#   'arr_estimated_utc': '2024-01-20 23:11',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '688',
#   'cs_flight_iata': 'AF688',
#   'status': 'active',
#   'duration': 590,
#   'delayed': 22,
#   'dep_delayed': 22,
#   'arr_delayed': 6,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705791900,
#   'dep_time_ts': 1705756500,
#   'arr_estimated_ts': 1705792260,
#   'dep_estimated_ts': 1705757820,
#   'dep_actual_ts': 1705757820},
#  {'airline_iata': 'LH',
#   'airline_icao': 'DLH',
#   'flight_iata': 'LH1035',
#   'flight_icao': 'DLH1035',
#   'flight_number': '1035',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '1',
#   'dep_gate': '64',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:37',
#   'dep_estimated_utc': '2024-01-20 13:37',
#   'dep_actual': '2024-01-20 14:37',
#   'dep_actual_utc': '2024-01-20 13:37',
#   'arr_iata': 'FRA',
#   'arr_icao': 'EDDF',
#   'arr_terminal': '1',
#   'arr_gate': 'A58',
#   'arr_baggage': '3',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'arr_estimated': '2024-01-20 15:47',
#   'arr_estimated_utc': '2024-01-20 14:47',
#   'arr_actual': '2024-01-20 15:47',
#   'arr_actual_utc': '2024-01-20 14:47',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 7,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'arr_estimated_ts': 1705762020,
#   'dep_estimated_ts': 1705757820,
#   'arr_actual_ts': 1705762020,
#   'dep_actual_ts': 1705757820},
#  {'airline_iata': 'UA',
#   'airline_icao': 'UAL',
#   'flight_iata': 'UA9323',
#   'flight_icao': 'UAL9323',
#   'flight_number': '9323',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '1',
#   'dep_gate': '64',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:37',
#   'dep_estimated_utc': '2024-01-20 13:37',
#   'dep_actual': '2024-01-20 14:37',
#   'dep_actual_utc': '2024-01-20 13:37',
#   'arr_iata': 'FRA',
#   'arr_icao': 'EDDF',
#   'arr_terminal': '1',
#   'arr_gate': 'A58',
#   'arr_baggage': '3',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'arr_estimated': '2024-01-20 15:47',
#   'arr_estimated_utc': '2024-01-20 14:47',
#   'arr_actual': '2024-01-20 15:47',
#   'arr_actual_utc': '2024-01-20 14:47',
#   'cs_airline_iata': 'LH',
#   'cs_flight_number': '1035',
#   'cs_flight_iata': 'LH1035',
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 7,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'arr_estimated_ts': 1705762020,
#   'dep_estimated_ts': 1705757820,
#   'arr_actual_ts': 1705762020,
#   'dep_actual_ts': 1705757820},
#  {'airline_iata': 'VS',
#   'airline_icao': 'VIR',
#   'flight_iata': 'VS6750',
#   'flight_icao': 'VIR6750',
#   'flight_number': '6750',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'M49',
#   'dep_time': '2024-01-20 14:15',
#   'dep_time_utc': '2024-01-20 13:15',
#   'dep_estimated': '2024-01-20 14:37',
#   'dep_estimated_utc': '2024-01-20 13:37',
#   'dep_actual': '2024-01-20 14:37',
#   'dep_actual_utc': '2024-01-20 13:37',
#   'arr_iata': 'ATL',
#   'arr_icao': 'KATL',
#   'arr_terminal': 'I',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 18:05',
#   'arr_time_utc': '2024-01-20 23:05',
#   'arr_estimated': '2024-01-20 18:11',
#   'arr_estimated_utc': '2024-01-20 23:11',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '688',
#   'cs_flight_iata': 'AF688',
#   'status': 'active',
#   'duration': 590,
#   'delayed': 22,
#   'dep_delayed': 22,
#   'arr_delayed': 6,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705791900,
#   'dep_time_ts': 1705756500,
#   'arr_estimated_ts': 1705792260,
#   'dep_estimated_ts': 1705757820,
#   'dep_actual_ts': 1705757820},
#  {'airline_iata': 'AF',
#   'airline_icao': 'AFR',
#   'flight_iata': 'AF54',
#   'flight_icao': 'AFR54',
#   'flight_number': '54',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'L30',
#   'dep_time': '2024-01-20 14:00',
#   'dep_time_utc': '2024-01-20 13:00',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'IAD',
#   'arr_icao': 'KIAD',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': '20',
#   'arr_time': '2024-01-20 16:40',
#   'arr_time_utc': '2024-01-20 21:40',
#   'arr_estimated': '2024-01-20 17:16',
#   'arr_estimated_utc': '2024-01-20 22:16',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 520,
#   'delayed': 36,
#   'dep_delayed': 38,
#   'arr_delayed': 36,
#   'aircraft_icao': 'B77W',
#   'arr_time_ts': 1705786800,
#   'dep_time_ts': 1705755600,
#   'arr_estimated_ts': 1705788960,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'AF',
#   'airline_icao': 'AFR',
#   'flight_iata': 'AF8234',
#   'flight_icao': 'AFR8234',
#   'flight_number': '8234',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F49',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'AMS',
#   'arr_icao': 'EHAM',
#   'arr_terminal': '2',
#   'arr_gate': 'C9',
#   'arr_baggage': '016',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'cs_airline_iata': 'KL',
#   'cs_flight_number': '1234',
#   'cs_flight_iata': 'KL1234',
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 8,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'CI',
#   'airline_icao': 'CAL',
#   'flight_iata': 'CI9482',
#   'flight_icao': 'CAL9482',
#   'flight_number': '9482',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F49',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'AMS',
#   'arr_icao': 'EHAM',
#   'arr_terminal': '2',
#   'arr_gate': 'C9',
#   'arr_baggage': '016',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'cs_airline_iata': 'KL',
#   'cs_flight_number': '1234',
#   'cs_flight_iata': 'KL1234',
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 8,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'DL',
#   'airline_icao': 'DAL',
#   'flight_iata': 'DL8496',
#   'flight_icao': 'DAL8496',
#   'flight_number': '8496',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'L30',
#   'dep_time': '2024-01-20 14:00',
#   'dep_time_utc': '2024-01-20 13:00',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'IAD',
#   'arr_icao': 'KIAD',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': '20',
#   'arr_time': '2024-01-20 16:40',
#   'arr_time_utc': '2024-01-20 21:40',
#   'arr_estimated': '2024-01-20 17:16',
#   'arr_estimated_utc': '2024-01-20 22:16',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '54',
#   'cs_flight_iata': 'AF54',
#   'status': 'active',
#   'duration': 520,
#   'delayed': 36,
#   'dep_delayed': 38,
#   'arr_delayed': 36,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705786800,
#   'dep_time_ts': 1705755600,
#   'arr_estimated_ts': 1705788960,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'DL',
#   'airline_icao': 'DAL',
#   'flight_iata': 'DL9474',
#   'flight_icao': 'DAL9474',
#   'flight_number': '9474',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F49',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'AMS',
#   'arr_icao': 'EHAM',
#   'arr_terminal': '2',
#   'arr_gate': 'C9',
#   'arr_baggage': '016',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'cs_airline_iata': 'KL',
#   'cs_flight_number': '1234',
#   'cs_flight_iata': 'KL1234',
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 8,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'GA',
#   'airline_icao': 'GIA',
#   'flight_iata': 'GA9539',
#   'flight_icao': 'GIA9539',
#   'flight_number': '9539',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F49',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'AMS',
#   'arr_icao': 'EHAM',
#   'arr_terminal': '2',
#   'arr_gate': 'C9',
#   'arr_baggage': '016',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'cs_airline_iata': 'KL',
#   'cs_flight_number': '1234',
#   'cs_flight_iata': 'KL1234',
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 8,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'KL',
#   'airline_icao': 'KLM',
#   'flight_iata': 'KL1234',
#   'flight_icao': 'KLM1234',
#   'flight_number': '1234',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F49',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'AMS',
#   'arr_icao': 'EHAM',
#   'arr_terminal': '2',
#   'arr_gate': 'C9',
#   'arr_baggage': '016',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 8,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'KL',
#   'airline_icao': 'KLM',
#   'flight_iata': 'KL2243',
#   'flight_icao': 'KLM2243',
#   'flight_number': '2243',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'L30',
#   'dep_time': '2024-01-20 14:00',
#   'dep_time_utc': '2024-01-20 13:00',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'IAD',
#   'arr_icao': 'KIAD',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': '20',
#   'arr_time': '2024-01-20 16:40',
#   'arr_time_utc': '2024-01-20 21:40',
#   'arr_estimated': '2024-01-20 17:16',
#   'arr_estimated_utc': '2024-01-20 22:16',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '54',
#   'cs_flight_iata': 'AF54',
#   'status': 'active',
#   'duration': 520,
#   'delayed': 36,
#   'dep_delayed': 38,
#   'arr_delayed': 36,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705786800,
#   'dep_time_ts': 1705755600,
#   'arr_estimated_ts': 1705788960,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'KQ',
#   'airline_icao': 'KQA',
#   'flight_iata': 'KQ1234',
#   'flight_icao': 'KQA1234',
#   'flight_number': '1234',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F49',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'AMS',
#   'arr_icao': 'EHAM',
#   'arr_terminal': '2',
#   'arr_gate': 'C9',
#   'arr_baggage': '016',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'cs_airline_iata': 'KL',
#   'cs_flight_number': '1234',
#   'cs_flight_iata': 'KL1234',
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 8,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'MF',
#   'airline_icao': 'CXA',
#   'flight_iata': 'MF9784',
#   'flight_icao': 'CXA9784',
#   'flight_number': '9784',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F49',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'AMS',
#   'arr_icao': 'EHAM',
#   'arr_terminal': '2',
#   'arr_gate': 'C9',
#   'arr_baggage': '016',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'cs_airline_iata': 'KL',
#   'cs_flight_number': '1234',
#   'cs_flight_iata': 'KL1234',
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 8,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'MK',
#   'airline_icao': 'MAU',
#   'flight_iata': 'MK7513',
#   'flight_icao': 'MAU7513',
#   'flight_number': '7513',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F49',
#   'dep_time': '2024-01-20 14:30',
#   'dep_time_utc': '2024-01-20 13:30',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'AMS',
#   'arr_icao': 'EHAM',
#   'arr_terminal': '2',
#   'arr_gate': 'C9',
#   'arr_baggage': '016',
#   'arr_time': '2024-01-20 15:50',
#   'arr_time_utc': '2024-01-20 14:50',
#   'cs_airline_iata': 'KL',
#   'cs_flight_number': '1234',
#   'cs_flight_iata': 'KL1234',
#   'status': 'landed',
#   'duration': 80,
#   'delayed': None,
#   'dep_delayed': 8,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705762200,
#   'dep_time_ts': 1705757400,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'VS',
#   'airline_icao': 'VIR',
#   'flight_iata': 'VS6756',
#   'flight_icao': 'VIR6756',
#   'flight_number': '6756',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'L30',
#   'dep_time': '2024-01-20 14:00',
#   'dep_time_utc': '2024-01-20 13:00',
#   'dep_estimated': '2024-01-20 14:38',
#   'dep_estimated_utc': '2024-01-20 13:38',
#   'dep_actual': '2024-01-20 14:38',
#   'dep_actual_utc': '2024-01-20 13:38',
#   'arr_iata': 'IAD',
#   'arr_icao': 'KIAD',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': '20',
#   'arr_time': '2024-01-20 16:40',
#   'arr_time_utc': '2024-01-20 21:40',
#   'arr_estimated': '2024-01-20 17:16',
#   'arr_estimated_utc': '2024-01-20 22:16',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '54',
#   'cs_flight_iata': 'AF54',
#   'status': 'active',
#   'duration': 520,
#   'delayed': 36,
#   'dep_delayed': 38,
#   'arr_delayed': 36,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705786800,
#   'dep_time_ts': 1705755600,
#   'arr_estimated_ts': 1705788960,
#   'dep_estimated_ts': 1705757880,
#   'dep_actual_ts': 1705757880},
#  {'airline_iata': 'AF',
#   'airline_icao': 'AFR',
#   'flight_iata': 'AF206',
#   'flight_icao': 'AFR206',
#   'flight_number': '206',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'K41',
#   'dep_time': '2024-01-20 13:50',
#   'dep_time_utc': '2024-01-20 12:50',
#   'dep_estimated': '2024-01-20 14:41',
#   'dep_estimated_utc': '2024-01-20 13:41',
#   'dep_actual': '2024-01-20 14:41',
#   'dep_actual_utc': '2024-01-20 13:41',
#   'arr_iata': 'BOM',
#   'arr_icao': 'VABB',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-21 03:00',
#   'arr_time_utc': '2024-01-20 21:30',
#   'arr_estimated': '2024-01-21 03:29',
#   'arr_estimated_utc': '2024-01-20 21:59',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 520,
#   'delayed': 29,
#   'dep_delayed': 51,
#   'arr_delayed': 29,
#   'aircraft_icao': 'A359',
#   'arr_time_ts': 1705786200,
#   'dep_time_ts': 1705755000,
#   'arr_estimated_ts': 1705787940,
#   'dep_estimated_ts': 1705758060,
#   'dep_actual_ts': 1705758060},
#  {'airline_iata': 'AF',
#   'airline_icao': 'AFR',
#   'flight_iata': 'AF702',
#   'flight_icao': 'AFR702',
#   'flight_number': '702',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'L44',
#   'dep_time': '2024-01-20 14:35',
#   'dep_time_utc': '2024-01-20 13:35',
#   'dep_estimated': '2024-01-20 14:41',
#   'dep_estimated_utc': '2024-01-20 13:41',
#   'dep_actual': '2024-01-20 14:41',
#   'dep_actual_utc': '2024-01-20 13:41',
#   'arr_iata': 'ABJ',
#   'arr_icao': 'DIAP',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 20:05',
#   'arr_time_utc': '2024-01-20 20:05',
#   'arr_estimated': '2024-01-20 20:08',
#   'arr_estimated_utc': '2024-01-20 20:08',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 390,
#   'delayed': 6,
#   'dep_delayed': 6,
#   'arr_delayed': 3,
#   'aircraft_icao': 'B77W',
#   'arr_time_ts': 1705781100,
#   'dep_time_ts': 1705757700,
#   'arr_estimated_ts': 1705781280,
#   'dep_estimated_ts': 1705758060,
#   'dep_actual_ts': 1705758060},
#  {'airline_iata': 'DL',
#   'airline_icao': 'DAL',
#   'flight_iata': 'DL8408',
#   'flight_icao': 'DAL8408',
#   'flight_number': '8408',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'K41',
#   'dep_time': '2024-01-20 13:50',
#   'dep_time_utc': '2024-01-20 12:50',
#   'dep_estimated': '2024-01-20 14:41',
#   'dep_estimated_utc': '2024-01-20 13:41',
#   'dep_actual': '2024-01-20 14:41',
#   'dep_actual_utc': '2024-01-20 13:41',
#   'arr_iata': 'BOM',
#   'arr_icao': 'VABB',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-21 03:00',
#   'arr_time_utc': '2024-01-20 21:30',
#   'arr_estimated': '2024-01-21 03:29',
#   'arr_estimated_utc': '2024-01-20 21:59',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '206',
#   'cs_flight_iata': 'AF206',
#   'status': 'active',
#   'duration': 520,
#   'delayed': 29,
#   'dep_delayed': 51,
#   'arr_delayed': 29,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705786200,
#   'dep_time_ts': 1705755000,
#   'arr_estimated_ts': 1705787940,
#   'dep_estimated_ts': 1705758060,
#   'dep_actual_ts': 1705758060},
#  {'airline_iata': 'DL',
#   'airline_icao': 'DAL',
#   'flight_iata': 'DL8574',
#   'flight_icao': 'DAL8574',
#   'flight_number': '8574',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'L44',
#   'dep_time': '2024-01-20 14:35',
#   'dep_time_utc': '2024-01-20 13:35',
#   'dep_estimated': '2024-01-20 14:41',
#   'dep_estimated_utc': '2024-01-20 13:41',
#   'dep_actual': '2024-01-20 14:41',
#   'dep_actual_utc': '2024-01-20 13:41',
#   'arr_iata': 'ABJ',
#   'arr_icao': 'DIAP',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 20:05',
#   'arr_time_utc': '2024-01-20 20:05',
#   'arr_estimated': '2024-01-20 20:08',
#   'arr_estimated_utc': '2024-01-20 20:08',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '702',
#   'cs_flight_iata': 'AF702',
#   'status': 'active',
#   'duration': 390,
#   'delayed': 6,
#   'dep_delayed': 6,
#   'arr_delayed': 3,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705781100,
#   'dep_time_ts': 1705757700,
#   'arr_estimated_ts': 1705781280,
#   'dep_estimated_ts': 1705758060,
#   'dep_actual_ts': 1705758060},
#  {'airline_iata': 'KL',
#   'airline_icao': 'KLM',
#   'flight_iata': 'KL2270',
#   'flight_icao': 'KLM2270',
#   'flight_number': '2270',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'L44',
#   'dep_time': '2024-01-20 14:35',
#   'dep_time_utc': '2024-01-20 13:35',
#   'dep_estimated': '2024-01-20 14:41',
#   'dep_estimated_utc': '2024-01-20 13:41',
#   'dep_actual': '2024-01-20 14:41',
#   'dep_actual_utc': '2024-01-20 13:41',
#   'arr_iata': 'ABJ',
#   'arr_icao': 'DIAP',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 20:05',
#   'arr_time_utc': '2024-01-20 20:05',
#   'arr_estimated': '2024-01-20 20:08',
#   'arr_estimated_utc': '2024-01-20 20:08',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '702',
#   'cs_flight_iata': 'AF702',
#   'status': 'active',
#   'duration': 390,
#   'delayed': 6,
#   'dep_delayed': 6,
#   'arr_delayed': 3,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705781100,
#   'dep_time_ts': 1705757700,
#   'arr_estimated_ts': 1705781280,
#   'dep_estimated_ts': 1705758060,
#   'dep_actual_ts': 1705758060},
#  {'airline_iata': 'KL',
#   'airline_icao': 'KLM',
#   'flight_iata': 'KL2398',
#   'flight_icao': 'KLM2398',
#   'flight_number': '2398',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'K41',
#   'dep_time': '2024-01-20 13:50',
#   'dep_time_utc': '2024-01-20 12:50',
#   'dep_estimated': '2024-01-20 14:41',
#   'dep_estimated_utc': '2024-01-20 13:41',
#   'dep_actual': '2024-01-20 14:41',
#   'dep_actual_utc': '2024-01-20 13:41',
#   'arr_iata': 'BOM',
#   'arr_icao': 'VABB',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-21 03:00',
#   'arr_time_utc': '2024-01-20 21:30',
#   'arr_estimated': '2024-01-21 03:29',
#   'arr_estimated_utc': '2024-01-20 21:59',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '206',
#   'cs_flight_iata': 'AF206',
#   'status': 'active',
#   'duration': 520,
#   'delayed': 29,
#   'dep_delayed': 51,
#   'arr_delayed': 29,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705786200,
#   'dep_time_ts': 1705755000,
#   'arr_estimated_ts': 1705787940,
#   'dep_estimated_ts': 1705758060,
#   'dep_actual_ts': 1705758060},
#  {'airline_iata': 'AF',
#   'airline_icao': 'AFR',
#   'flight_iata': 'AF1774',
#   'flight_icao': 'AFR1774',
#   'flight_number': '1774',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': 'A321',
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'AM',
#   'airline_icao': 'AMX',
#   'flight_iata': 'AM5765',
#   'flight_icao': 'AMX5765',
#   'flight_number': '5765',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'AZ',
#   'airline_icao': 'ITY',
#   'flight_iata': 'AZ2966',
#   'flight_icao': 'ITY2966',
#   'flight_number': '2966',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'DL',
#   'airline_icao': 'DAL',
#   'flight_iata': 'DL8545',
#   'flight_icao': 'DAL8545',
#   'flight_number': '8545',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'EY',
#   'airline_icao': 'ETD',
#   'flight_iata': 'EY5943',
#   'flight_icao': 'ETD5943',
#   'flight_number': '5943',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'G3',
#   'airline_icao': 'GLO',
#   'flight_iata': 'G35227',
#   'flight_icao': 'GLO5227',
#   'flight_number': '5227',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'KQ',
#   'airline_icao': 'KQA',
#   'flight_iata': 'KQ3254',
#   'flight_icao': 'KQA3254',
#   'flight_number': '3254',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'MK',
#   'airline_icao': 'MAU',
#   'flight_iata': 'MK9652',
#   'flight_icao': 'MAU9652',
#   'flight_number': '9652',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'MU',
#   'airline_icao': 'CES',
#   'flight_iata': 'MU1689',
#   'flight_icao': 'CES1689',
#   'flight_number': '1689',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'SV',
#   'airline_icao': 'SVA',
#   'flight_iata': 'SV6095',
#   'flight_icao': 'SVA6095',
#   'flight_number': '6095',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'UU',
#   'airline_icao': 'REU',
#   'flight_iata': 'UU8774',
#   'flight_icao': 'REU8774',
#   'flight_number': '8774',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'VN',
#   'airline_icao': 'HVN',
#   'flight_iata': 'VN3686',
#   'flight_icao': 'HVN3686',
#   'flight_number': '3686',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F55',
#   'dep_time': '2024-01-20 14:05',
#   'dep_time_utc': '2024-01-20 13:05',
#   'dep_estimated': '2024-01-20 14:45',
#   'dep_estimated_utc': '2024-01-20 13:45',
#   'dep_actual': '2024-01-20 14:45',
#   'dep_actual_utc': '2024-01-20 13:45',
#   'arr_iata': 'OSL',
#   'arr_icao': 'ENGM',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 16:25',
#   'arr_time_utc': '2024-01-20 15:25',
#   'arr_estimated': '2024-01-20 17:12',
#   'arr_estimated_utc': '2024-01-20 16:12',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1774',
#   'cs_flight_iata': 'AF1774',
#   'status': 'active',
#   'duration': 140,
#   'delayed': 40,
#   'dep_delayed': 40,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705764300,
#   'dep_time_ts': 1705755900,
#   'arr_estimated_ts': 1705767120,
#   'dep_estimated_ts': 1705758300,
#   'dep_actual_ts': 1705758300},
#  {'airline_iata': 'AC',
#   'airline_icao': 'ACA',
#   'flight_iata': 'AC3297',
#   'flight_icao': 'ACA3297',
#   'flight_number': '3297',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '1',
#   'dep_gate': '12',
#   'dep_time': '2024-01-20 11:40',
#   'dep_time_utc': '2024-01-20 10:40',
#   'dep_estimated': '2024-01-20 14:46',
#   'dep_estimated_utc': '2024-01-20 13:46',
#   'dep_actual': '2024-01-20 14:46',
#   'dep_actual_utc': '2024-01-20 13:46',
#   'arr_iata': 'ORD',
#   'arr_icao': 'KORD',
#   'arr_terminal': '5',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 14:15',
#   'arr_time_utc': '2024-01-20 20:15',
#   'arr_estimated': '2024-01-20 16:38',
#   'arr_estimated_utc': '2024-01-20 22:38',
#   'cs_airline_iata': 'UA',
#   'cs_flight_number': '986',
#   'cs_flight_iata': 'UA986',
#   'status': 'active',
#   'duration': 575,
#   'delayed': 186,
#   'dep_delayed': 186,
#   'arr_delayed': 143,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705781700,
#   'dep_time_ts': 1705747200,
#   'arr_estimated_ts': 1705790280,
#   'dep_estimated_ts': 1705758360,
#   'dep_actual_ts': 1705758360},
#  {'airline_iata': 'LH',
#   'airline_icao': 'DLH',
#   'flight_iata': 'LH9334',
#   'flight_icao': 'DLH9334',
#   'flight_number': '9334',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '1',
#   'dep_gate': '12',
#   'dep_time': '2024-01-20 11:40',
#   'dep_time_utc': '2024-01-20 10:40',
#   'dep_estimated': '2024-01-20 14:46',
#   'dep_estimated_utc': '2024-01-20 13:46',
#   'dep_actual': '2024-01-20 14:46',
#   'dep_actual_utc': '2024-01-20 13:46',
#   'arr_iata': 'ORD',
#   'arr_icao': 'KORD',
#   'arr_terminal': '5',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 14:15',
#   'arr_time_utc': '2024-01-20 20:15',
#   'arr_estimated': '2024-01-20 16:38',
#   'arr_estimated_utc': '2024-01-20 22:38',
#   'cs_airline_iata': 'UA',
#   'cs_flight_number': '986',
#   'cs_flight_iata': 'UA986',
#   'status': 'active',
#   'duration': 575,
#   'delayed': 186,
#   'dep_delayed': 186,
#   'arr_delayed': 143,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705781700,
#   'dep_time_ts': 1705747200,
#   'arr_estimated_ts': 1705790280,
#   'dep_estimated_ts': 1705758360,
#   'dep_actual_ts': 1705758360},
#  {'airline_iata': 'OS',
#   'airline_icao': 'AUA',
#   'flight_iata': 'OS7759',
#   'flight_icao': 'AUA7759',
#   'flight_number': '7759',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '1',
#   'dep_gate': '12',
#   'dep_time': '2024-01-20 11:40',
#   'dep_time_utc': '2024-01-20 10:40',
#   'dep_estimated': '2024-01-20 14:46',
#   'dep_estimated_utc': '2024-01-20 13:46',
#   'dep_actual': '2024-01-20 14:46',
#   'dep_actual_utc': '2024-01-20 13:46',
#   'arr_iata': 'ORD',
#   'arr_icao': 'KORD',
#   'arr_terminal': '5',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 14:15',
#   'arr_time_utc': '2024-01-20 20:15',
#   'arr_estimated': '2024-01-20 16:38',
#   'arr_estimated_utc': '2024-01-20 22:38',
#   'cs_airline_iata': 'UA',
#   'cs_flight_number': '986',
#   'cs_flight_iata': 'UA986',
#   'status': 'active',
#   'duration': 575,
#   'delayed': 186,
#   'dep_delayed': 186,
#   'arr_delayed': 143,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705781700,
#   'dep_time_ts': 1705747200,
#   'arr_estimated_ts': 1705790280,
#   'dep_estimated_ts': 1705758360,
#   'dep_actual_ts': 1705758360},
#  {'airline_iata': 'SN',
#   'airline_icao': 'BEL',
#   'flight_iata': 'SN9108',
#   'flight_icao': 'BEL9108',
#   'flight_number': '9108',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '1',
#   'dep_gate': '12',
#   'dep_time': '2024-01-20 11:40',
#   'dep_time_utc': '2024-01-20 10:40',
#   'dep_estimated': '2024-01-20 14:46',
#   'dep_estimated_utc': '2024-01-20 13:46',
#   'dep_actual': '2024-01-20 14:46',
#   'dep_actual_utc': '2024-01-20 13:46',
#   'arr_iata': 'ORD',
#   'arr_icao': 'KORD',
#   'arr_terminal': '5',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 14:15',
#   'arr_time_utc': '2024-01-20 20:15',
#   'arr_estimated': '2024-01-20 16:38',
#   'arr_estimated_utc': '2024-01-20 22:38',
#   'cs_airline_iata': 'UA',
#   'cs_flight_number': '986',
#   'cs_flight_iata': 'UA986',
#   'status': 'active',
#   'duration': 575,
#   'delayed': 186,
#   'dep_delayed': 186,
#   'arr_delayed': 143,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705781700,
#   'dep_time_ts': 1705747200,
#   'arr_estimated_ts': 1705790280,
#   'dep_estimated_ts': 1705758360,
#   'dep_actual_ts': 1705758360},
#  {'airline_iata': 'UA',
#   'airline_icao': 'UAL',
#   'flight_iata': 'UA986',
#   'flight_icao': 'UAL986',
#   'flight_number': '986',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '1',
#   'dep_gate': '12',
#   'dep_time': '2024-01-20 11:40',
#   'dep_time_utc': '2024-01-20 10:40',
#   'dep_estimated': '2024-01-20 14:46',
#   'dep_estimated_utc': '2024-01-20 13:46',
#   'dep_actual': '2024-01-20 14:46',
#   'dep_actual_utc': '2024-01-20 13:46',
#   'arr_iata': 'ORD',
#   'arr_icao': 'KORD',
#   'arr_terminal': '5',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 14:15',
#   'arr_time_utc': '2024-01-20 20:15',
#   'arr_estimated': '2024-01-20 16:38',
#   'arr_estimated_utc': '2024-01-20 22:38',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 575,
#   'delayed': 186,
#   'dep_delayed': 186,
#   'arr_delayed': 143,
#   'aircraft_icao': 'B763',
#   'arr_time_ts': 1705781700,
#   'dep_time_ts': 1705747200,
#   'arr_estimated_ts': 1705790280,
#   'dep_estimated_ts': 1705758360,
#   'dep_actual_ts': 1705758360},
#  {'airline_iata': 'AF',
#   'airline_icao': 'AFR',
#   'flight_iata': 'AF804',
#   'flight_icao': 'AFR804',
#   'flight_number': '804',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2E',
#   'dep_gate': 'L45',
#   'dep_time': '2024-01-20 14:50',
#   'dep_time_utc': '2024-01-20 13:50',
#   'dep_estimated': '2024-01-20 14:49',
#   'dep_estimated_utc': '2024-01-20 13:49',
#   'dep_actual': '2024-01-20 14:49',
#   'dep_actual_utc': '2024-01-20 13:49',
#   'arr_iata': 'COO',
#   'arr_icao': 'DBBB',
#   'arr_terminal': None,
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 21:10',
#   'arr_time_utc': '2024-01-20 20:10',
#   'arr_estimated': '2024-01-20 21:17',
#   'arr_estimated_utc': '2024-01-20 20:17',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 380,
#   'delayed': 7,
#   'dep_delayed': None,
#   'arr_delayed': 7,
#   'aircraft_icao': 'A332',
#   'arr_time_ts': 1705781400,
#   'dep_time_ts': 1705758600,
#   'arr_estimated_ts': 1705781820,
#   'dep_estimated_ts': 1705758540,
#   'dep_actual_ts': 1705758540},
#  {'airline_iata': 'DL',
#   'airline_icao': 'DAL',
#   'flight_iata': 'DL8620',
# ...
#   'dep_terminal': '2D',
#   'dep_gate': 'D56',
#   'dep_time': '2024-01-20 15:00',
#   'dep_time_utc': '2024-01-20 14:00',
#   'dep_estimated': '2024-01-20 15:09',
#   'dep_estimated_utc': '2024-01-20 14:09',
#   'dep_actual': '2024-01-20 15:09',
#   'dep_actual_utc': '2024-01-20 14:09',
#   'arr_iata': 'PRG',
#   'arr_icao': 'LKPR',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': '24',
#   'arr_time': '2024-01-20 16:45',
#   'arr_time_utc': '2024-01-20 15:45',
#   'arr_estimated': '2024-01-20 16:59',
#   'arr_estimated_utc': '2024-01-20 15:59',
#   'cs_airline_iata': 'OK',
#   'cs_flight_number': '761',
#   'cs_flight_iata': 'OK761',
#   'status': 'active',
#   'duration': 105,
#   'delayed': 9,
#   'dep_delayed': 9,
#   'arr_delayed': 14,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705765500,
#   'dep_time_ts': 1705759200,
#   'arr_estimated_ts': 1705766340,
#   'dep_estimated_ts': 1705759740,
#   'dep_actual_ts': 1705759740},
#  {'airline_iata': 'CZ',
#   'airline_icao': 'CSN',
#   'flight_iata': 'CZ7304',
#   'flight_icao': 'CSN7304',
#   'flight_number': '7304',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2D',
#   'dep_gate': 'D56',
#   'dep_time': '2024-01-20 15:00',
#   'dep_time_utc': '2024-01-20 14:00',
#   'dep_estimated': '2024-01-20 15:09',
#   'dep_estimated_utc': '2024-01-20 14:09',
#   'dep_actual': '2024-01-20 15:09',
#   'dep_actual_utc': '2024-01-20 14:09',
#   'arr_iata': 'PRG',
#   'arr_icao': 'LKPR',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': '24',
#   'arr_time': '2024-01-20 16:45',
#   'arr_time_utc': '2024-01-20 15:45',
#   'arr_estimated': '2024-01-20 16:59',
#   'arr_estimated_utc': '2024-01-20 15:59',
#   'cs_airline_iata': 'OK',
#   'cs_flight_number': '761',
#   'cs_flight_iata': 'OK761',
#   'status': 'active',
#   'duration': 105,
#   'delayed': 9,
#   'dep_delayed': 9,
#   'arr_delayed': 14,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705765500,
#   'dep_time_ts': 1705759200,
#   'arr_estimated_ts': 1705766340,
#   'dep_estimated_ts': 1705759740,
#   'dep_actual_ts': 1705759740},
#  {'airline_iata': 'DL',
#   'airline_icao': 'DAL',
#   'flight_iata': 'DL6565',
#   'flight_icao': 'DAL6565',
#   'flight_number': '6565',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2D',
#   'dep_gate': 'D56',
#   'dep_time': '2024-01-20 15:00',
#   'dep_time_utc': '2024-01-20 14:00',
#   'dep_estimated': '2024-01-20 15:09',
#   'dep_estimated_utc': '2024-01-20 14:09',
#   'dep_actual': '2024-01-20 15:09',
#   'dep_actual_utc': '2024-01-20 14:09',
#   'arr_iata': 'PRG',
#   'arr_icao': 'LKPR',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': '24',
#   'arr_time': '2024-01-20 16:45',
#   'arr_time_utc': '2024-01-20 15:45',
#   'arr_estimated': '2024-01-20 16:59',
#   'arr_estimated_utc': '2024-01-20 15:59',
#   'cs_airline_iata': 'OK',
#   'cs_flight_number': '761',
#   'cs_flight_iata': 'OK761',
#   'status': 'active',
#   'duration': 105,
#   'delayed': 9,
#   'dep_delayed': 9,
#   'arr_delayed': 14,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705765500,
#   'dep_time_ts': 1705759200,
#   'arr_estimated_ts': 1705766340,
#   'dep_estimated_ts': 1705759740,
#   'dep_actual_ts': 1705759740},
#  {'airline_iata': 'ME',
#   'airline_icao': 'MEA',
#   'flight_iata': 'ME4761',
#   'flight_icao': 'MEA4761',
#   'flight_number': '4761',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2D',
#   'dep_gate': 'D56',
#   'dep_time': '2024-01-20 15:00',
#   'dep_time_utc': '2024-01-20 14:00',
#   'dep_estimated': '2024-01-20 15:09',
#   'dep_estimated_utc': '2024-01-20 14:09',
#   'dep_actual': '2024-01-20 15:09',
#   'dep_actual_utc': '2024-01-20 14:09',
#   'arr_iata': 'PRG',
#   'arr_icao': 'LKPR',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': '24',
#   'arr_time': '2024-01-20 16:45',
#   'arr_time_utc': '2024-01-20 15:45',
#   'arr_estimated': '2024-01-20 16:59',
#   'arr_estimated_utc': '2024-01-20 15:59',
#   'cs_airline_iata': 'OK',
#   'cs_flight_number': '761',
#   'cs_flight_iata': 'OK761',
#   'status': 'active',
#   'duration': 105,
#   'delayed': 9,
#   'dep_delayed': 9,
#   'arr_delayed': 14,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705765500,
#   'dep_time_ts': 1705759200,
#   'arr_estimated_ts': 1705766340,
#   'dep_estimated_ts': 1705759740,
#   'dep_actual_ts': 1705759740},
#  {'airline_iata': 'MU',
#   'airline_icao': 'CES',
#   'flight_iata': 'MU4999',
#   'flight_icao': 'CES4999',
#   'flight_number': '4999',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2D',
#   'dep_gate': 'D56',
#   'dep_time': '2024-01-20 15:00',
#   'dep_time_utc': '2024-01-20 14:00',
#   'dep_estimated': '2024-01-20 15:09',
#   'dep_estimated_utc': '2024-01-20 14:09',
#   'dep_actual': '2024-01-20 15:09',
#   'dep_actual_utc': '2024-01-20 14:09',
#   'arr_iata': 'PRG',
#   'arr_icao': 'LKPR',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': '24',
#   'arr_time': '2024-01-20 16:45',
#   'arr_time_utc': '2024-01-20 15:45',
#   'arr_estimated': '2024-01-20 16:59',
#   'arr_estimated_utc': '2024-01-20 15:59',
#   'cs_airline_iata': 'OK',
#   'cs_flight_number': '761',
#   'cs_flight_iata': 'OK761',
#   'status': 'active',
#   'duration': 105,
#   'delayed': 9,
#   'dep_delayed': 9,
#   'arr_delayed': 14,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705765500,
#   'dep_time_ts': 1705759200,
#   'arr_estimated_ts': 1705766340,
#   'dep_estimated_ts': 1705759740,
#   'dep_actual_ts': 1705759740},
#  {'airline_iata': 'OK',
#   'airline_icao': 'CSA',
#   'flight_iata': 'OK761',
#   'flight_icao': 'CSA761',
#   'flight_number': '761',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2D',
#   'dep_gate': 'D56',
#   'dep_time': '2024-01-20 15:00',
#   'dep_time_utc': '2024-01-20 14:00',
#   'dep_estimated': '2024-01-20 15:09',
#   'dep_estimated_utc': '2024-01-20 14:09',
#   'dep_actual': '2024-01-20 15:09',
#   'dep_actual_utc': '2024-01-20 14:09',
#   'arr_iata': 'PRG',
#   'arr_icao': 'LKPR',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': '24',
#   'arr_time': '2024-01-20 16:45',
#   'arr_time_utc': '2024-01-20 15:45',
#   'arr_estimated': '2024-01-20 16:59',
#   'arr_estimated_utc': '2024-01-20 15:59',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 105,
#   'delayed': 9,
#   'dep_delayed': 9,
#   'arr_delayed': 14,
#   'aircraft_icao': 'A320',
#   'arr_time_ts': 1705765500,
#   'dep_time_ts': 1705759200,
#   'arr_estimated_ts': 1705766340,
#   'dep_estimated_ts': 1705759740,
#   'dep_actual_ts': 1705759740},
#  {'airline_iata': 'QS',
#   'airline_icao': 'TVS',
#   'flight_iata': 'QS8761',
#   'flight_icao': 'TVS8761',
#   'flight_number': '8761',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2D',
#   'dep_gate': 'D56',
#   'dep_time': '2024-01-20 15:00',
#   'dep_time_utc': '2024-01-20 14:00',
#   'dep_estimated': '2024-01-20 15:09',
#   'dep_estimated_utc': '2024-01-20 14:09',
#   'dep_actual': '2024-01-20 15:09',
#   'dep_actual_utc': '2024-01-20 14:09',
#   'arr_iata': 'PRG',
#   'arr_icao': 'LKPR',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': '24',
#   'arr_time': '2024-01-20 16:45',
#   'arr_time_utc': '2024-01-20 15:45',
#   'arr_estimated': '2024-01-20 16:59',
#   'arr_estimated_utc': '2024-01-20 15:59',
#   'cs_airline_iata': 'OK',
#   'cs_flight_number': '761',
#   'cs_flight_iata': 'OK761',
#   'status': 'active',
#   'duration': 105,
#   'delayed': 9,
#   'dep_delayed': 9,
#   'arr_delayed': 14,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705765500,
#   'dep_time_ts': 1705759200,
#   'arr_estimated_ts': 1705766340,
#   'dep_estimated_ts': 1705759740,
#   'dep_actual_ts': 1705759740},
#  {'airline_iata': 'SV',
#   'airline_icao': 'SVA',
#   'flight_iata': 'SV6041',
#   'flight_icao': 'SVA6041',
#   'flight_number': '6041',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2D',
#   'dep_gate': 'D56',
#   'dep_time': '2024-01-20 15:00',
#   'dep_time_utc': '2024-01-20 14:00',
#   'dep_estimated': '2024-01-20 15:09',
#   'dep_estimated_utc': '2024-01-20 14:09',
#   'dep_actual': '2024-01-20 15:09',
#   'dep_actual_utc': '2024-01-20 14:09',
#   'arr_iata': 'PRG',
#   'arr_icao': 'LKPR',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': '24',
#   'arr_time': '2024-01-20 16:45',
#   'arr_time_utc': '2024-01-20 15:45',
#   'arr_estimated': '2024-01-20 16:59',
#   'arr_estimated_utc': '2024-01-20 15:59',
#   'cs_airline_iata': 'OK',
#   'cs_flight_number': '761',
#   'cs_flight_iata': 'OK761',
#   'status': 'active',
#   'duration': 105,
#   'delayed': 9,
#   'dep_delayed': 9,
#   'arr_delayed': 14,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705765500,
#   'dep_time_ts': 1705759200,
#   'arr_estimated_ts': 1705766340,
#   'dep_estimated_ts': 1705759740,
#   'dep_actual_ts': 1705759740},
#  {'airline_iata': 'AF',
#   'airline_icao': 'AFR',
#   'flight_iata': 'AF1196',
#   'flight_icao': 'AFR1196',
#   'flight_number': '1196',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': None,
#   'dep_time': '2024-01-20 15:10',
#   'dep_time_utc': '2024-01-20 14:10',
#   'dep_estimated': '2024-01-20 15:12',
#   'dep_estimated_utc': '2024-01-20 14:12',
#   'dep_actual': '2024-01-20 15:12',
#   'dep_actual_utc': '2024-01-20 14:12',
#   'arr_iata': 'CMN',
#   'arr_icao': 'GMMN',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 18:15',
#   'arr_time_utc': '2024-01-20 17:15',
#   'arr_estimated': '2024-01-20 18:22',
#   'arr_estimated_utc': '2024-01-20 17:22',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 185,
#   'delayed': 2,
#   'dep_delayed': 2,
#   'arr_delayed': 7,
#   'aircraft_icao': 'A319',
#   'arr_time_ts': 1705770900,
#   'dep_time_ts': 1705759800,
#   'arr_estimated_ts': 1705771320,
#   'dep_estimated_ts': 1705759920,
#   'dep_actual_ts': 1705759920},
#  {'airline_iata': 'DL',
#   'airline_icao': 'DAL',
#   'flight_iata': 'DL8435',
#   'flight_icao': 'DAL8435',
#   'flight_number': '8435',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': None,
#   'dep_time': '2024-01-20 15:10',
#   'dep_time_utc': '2024-01-20 14:10',
#   'dep_estimated': '2024-01-20 15:12',
#   'dep_estimated_utc': '2024-01-20 14:12',
#   'dep_actual': '2024-01-20 15:12',
#   'dep_actual_utc': '2024-01-20 14:12',
#   'arr_iata': 'CMN',
#   'arr_icao': 'GMMN',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 18:15',
#   'arr_time_utc': '2024-01-20 17:15',
#   'arr_estimated': '2024-01-20 18:22',
#   'arr_estimated_utc': '2024-01-20 17:22',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1196',
#   'cs_flight_iata': 'AF1196',
#   'status': 'active',
#   'duration': 185,
#   'delayed': 2,
#   'dep_delayed': 2,
#   'arr_delayed': 7,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705770900,
#   'dep_time_ts': 1705759800,
#   'arr_estimated_ts': 1705771320,
#   'dep_estimated_ts': 1705759920,
#   'dep_actual_ts': 1705759920},
#  {'airline_iata': 'KL',
#   'airline_icao': 'KLM',
#   'flight_iata': 'KL2042',
#   'flight_icao': 'KLM2042',
#   'flight_number': '2042',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': None,
#   'dep_time': '2024-01-20 15:10',
#   'dep_time_utc': '2024-01-20 14:10',
#   'dep_estimated': '2024-01-20 15:12',
#   'dep_estimated_utc': '2024-01-20 14:12',
#   'dep_actual': '2024-01-20 15:12',
#   'dep_actual_utc': '2024-01-20 14:12',
#   'arr_iata': 'CMN',
#   'arr_icao': 'GMMN',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 18:15',
#   'arr_time_utc': '2024-01-20 17:15',
#   'arr_estimated': '2024-01-20 18:22',
#   'arr_estimated_utc': '2024-01-20 17:22',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1196',
#   'cs_flight_iata': 'AF1196',
#   'status': 'active',
#   'duration': 185,
#   'delayed': 2,
#   'dep_delayed': 2,
#   'arr_delayed': 7,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705770900,
#   'dep_time_ts': 1705759800,
#   'arr_estimated_ts': 1705771320,
#   'dep_estimated_ts': 1705759920,
#   'dep_actual_ts': 1705759920},
#  {'airline_iata': 'AC',
#   'airline_icao': 'ACA',
#   'flight_iata': 'AC2902',
#   'flight_icao': 'ACA2902',
#   'flight_number': '2902',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '1',
#   'dep_gate': '28',
#   'dep_time': '2024-01-20 14:50',
#   'dep_time_utc': '2024-01-20 13:50',
#   'dep_estimated': '2024-01-20 15:15',
#   'dep_estimated_utc': '2024-01-20 14:15',
#   'dep_actual': '2024-01-20 15:15',
#   'dep_actual_utc': '2024-01-20 14:15',
#   'arr_iata': 'CAI',
#   'arr_icao': 'HECA',
#   'arr_terminal': '3',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 20:10',
#   'arr_time_utc': '2024-01-20 18:10',
#   'arr_estimated': '2024-01-20 20:57',
#   'arr_estimated_utc': '2024-01-20 18:57',
#   'cs_airline_iata': 'MS',
#   'cs_flight_number': '800',
#   'cs_flight_iata': 'MS800',
#   'status': 'active',
#   'duration': 260,
#   'delayed': 47,
#   'dep_delayed': 25,
#   'arr_delayed': 47,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705774200,
#   'dep_time_ts': 1705758600,
#   'arr_estimated_ts': 1705777020,
#   'dep_estimated_ts': 1705760100,
#   'dep_actual_ts': 1705760100},
#  {'airline_iata': 'MS',
#   'airline_icao': 'MSR',
#   'flight_iata': 'MS800',
#   'flight_icao': 'MSR800',
#   'flight_number': '800',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '1',
#   'dep_gate': '28',
#   'dep_time': '2024-01-20 14:50',
#   'dep_time_utc': '2024-01-20 13:50',
#   'dep_estimated': '2024-01-20 15:15',
#   'dep_estimated_utc': '2024-01-20 14:15',
#   'dep_actual': '2024-01-20 15:15',
#   'dep_actual_utc': '2024-01-20 14:15',
#   'arr_iata': 'CAI',
#   'arr_icao': 'HECA',
#   'arr_terminal': '3',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 20:10',
#   'arr_time_utc': '2024-01-20 18:10',
#   'arr_estimated': '2024-01-20 20:57',
#   'arr_estimated_utc': '2024-01-20 18:57',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 260,
#   'delayed': 47,
#   'dep_delayed': 25,
#   'arr_delayed': 47,
#   'aircraft_icao': 'B789',
#   'arr_time_ts': 1705774200,
#   'dep_time_ts': 1705758600,
#   'arr_estimated_ts': 1705777020,
#   'dep_estimated_ts': 1705760100,
#   'dep_actual_ts': 1705760100},
#  {'airline_iata': 'AF',
#   'airline_icao': 'AFR',
#   'flight_iata': 'AF1062',
#   'flight_icao': 'AFR1062',
#   'flight_number': '1062',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F30',
#   'dep_time': '2024-01-20 15:15',
#   'dep_time_utc': '2024-01-20 14:15',
#   'dep_estimated': '2024-01-20 15:16',
#   'dep_estimated_utc': '2024-01-20 14:16',
#   'dep_actual': '2024-01-20 15:16',
#   'dep_actual_utc': '2024-01-20 14:16',
#   'arr_iata': 'ARN',
#   'arr_icao': 'ESSA',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 17:55',
#   'arr_time_utc': '2024-01-20 16:55',
#   'arr_estimated': '2024-01-20 17:52',
#   'arr_estimated_utc': '2024-01-20 16:52',
#   'cs_airline_iata': None,
#   'cs_flight_number': None,
#   'cs_flight_iata': None,
#   'status': 'active',
#   'duration': 160,
#   'delayed': 1,
#   'dep_delayed': 1,
#   'arr_delayed': None,
#   'aircraft_icao': 'BCS3',
#   'arr_time_ts': 1705769700,
#   'dep_time_ts': 1705760100,
#   'arr_estimated_ts': 1705769520,
#   'dep_estimated_ts': 1705760160,
#   'dep_actual_ts': 1705760160},
#  {'airline_iata': 'AM',
#   'airline_icao': 'AMX',
#   'flight_iata': 'AM5705',
#   'flight_icao': 'AMX5705',
#   'flight_number': '5705',
#   'dep_iata': 'CDG',
#   'dep_icao': 'LFPG',
#   'dep_terminal': '2F',
#   'dep_gate': 'F30',
#   'dep_time': '2024-01-20 15:15',
#   'dep_time_utc': '2024-01-20 14:15',
#   'dep_estimated': '2024-01-20 15:16',
#   'dep_estimated_utc': '2024-01-20 14:16',
#   'dep_actual': '2024-01-20 15:16',
#   'dep_actual_utc': '2024-01-20 14:16',
#   'arr_iata': 'ARN',
#   'arr_icao': 'ESSA',
#   'arr_terminal': '2',
#   'arr_gate': None,
#   'arr_baggage': None,
#   'arr_time': '2024-01-20 17:55',
#   'arr_time_utc': '2024-01-20 16:55',
#   'arr_estimated': '2024-01-20 17:52',
#   'arr_estimated_utc': '2024-01-20 16:52',
#   'cs_airline_iata': 'AF',
#   'cs_flight_number': '1062',
#   'cs_flight_iata': 'AF1062',
#   'status': 'active',
#   'duration': 160,
#   'delayed': 1,
#   'dep_delayed': 1,
#   'arr_delayed': None,
#   'aircraft_icao': None,
#   'arr_time_ts': 1705769700,
#   'dep_time_ts': 1705760100,
#   'arr_estimated_ts': 1705769520,
#   'dep_estimated_ts': 1705760160,
#   'dep_actual_ts': 1705760160}]

# %% [markdown]
# Get sample of api request for connections between given airports

# %%
DF = parse_response(res_ex)
DF.head()
# Out:
#    dep  arr  time
# 0  CDG  CFK   155
# 1  CDG  ALG   135
# 2  CDG  FRA    80
# 3  CDG  ATL   590
# 4  CDG  ATL   590

# %%
filter_clean_codes(DF, CODES)
# Out:
#    dep  arr  time
# 0  CDG  FRA    80
# 1  CDG  AMS    80
# 2  CDG  OSL   140
# 3  CDG  GOT   125
# 4  CDG  CPH   115
# 5  CDG  TLS    80
# 6  CDG  ZRH    75
# 7  CDG  PRG   105
# 8  CDG  ARN   160

# %% [markdown]
# ## Measure performance / Analytics of Flights

# %%
Flights_europe = pd.read_csv("./datasets/europe_flights.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [115], in <cell line: 1>()
# ----> 1 Flights_europe = pd.read_csv("./datasets/europe_flights.csv", index_col=True)
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439 self.nrows = options.pop("nrows", None)
#    1441 self._check_file_or_buffer(f, engine)
# -> 1442 self.options, self.engine = self._clean_options(options, engine)
#    1444 if "has_index_names" in kwds:
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader._clean_options(self, options, engine)
#    1615 validate_header_arg(options["header"])
#    1617 if index_col is True:
# -> 1618     raise ValueError("The value of index_col couldn't be 'True'")
#    1619 if is_index_col(index_col):
#    1620     if not isinstance(index_col, (list, tuple, np.ndarray)):
#
# ValueError: The value of index_col couldn't be 'True'

# %%
Flights_europe
# Out:
#       Unnamed: 0           route   time
# 0              0  {'AAL', 'AMS'}   85.0
# 1              1  {'AAQ', 'LED'}  170.0
# 2              2  {'AMS', 'ABZ'}   85.0
# 3              3  {'ABZ', 'LGW'}   95.0
# 4              4  {'ACE', 'AGP'}  130.0
# ...          ...             ...    ...
# 1464        1464  {'ZRH', 'OTP'}  150.0
# 1465        1465  {'ZRH', 'PRN'}  127.5
# 1466        1466  {'ZRH', 'RVN'}  205.0
# 1467        1467  {'ZRH', 'STR'}   45.0
# 1468        1468  {'ZTH', 'ATH'}   62.5
#
# [1469 rows x 3 columns]
